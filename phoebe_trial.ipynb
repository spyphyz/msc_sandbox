# %%
"""https://phoebe-project.org/
https://phoebe-project.org/docs/2.4/examples
https://phoebe-project.org/docs/2.4/tutorials"""
# Out:
# 'https://phoebe-project.org/'

# %%
import phoebe
# Out:
# PHOEBE: passband "Bolometric:900-40000" has a newer version available.  Run phoebe.list_passband_online_history("Bolometric:900-40000") to get a list of available changes and phoebe.update_passband("Bolometric:900-40000") or phoebe.update_all_passbands() to update.
# PHOEBE: passband "Johnson:V" has a newer version available.  Run phoebe.list_passband_online_history("Johnson:V") to get a list of available changes and phoebe.update_passband("Johnson:V") or phoebe.update_all_passbands() to update.

# %%
phoebe.list_passband_online_history("Bolometric:900-40000")
# Out:
# {'Thu Oct 24 11:17:44 2024': 'blackbody intensities w/o extinction added.',
#  'Thu Oct 24 11:21:11 2024': 'ck2004 intensities w/o extinction added.',
#  'Thu Oct 24 11:21:16 2024': 'LD coefficients for ck2004 added.',
#  'Thu Oct 24 11:21:20 2024': 'LD integrals for ck2004 added.',
#  'Thu Oct 24 11:23:26 2024': 'phoenix intensities w/o extinction added.',
#  'Thu Oct 24 11:23:35 2024': 'LD coefficients for phoenix added.',
#  'Thu Oct 24 11:23:39 2024': 'LD integrals for phoenix added.',
#  'Thu Oct 31 11:32:54 2024': 'This version fixes a bug in extinction tables.'}

# %%
phoebe.update_all_passbands()

# %%
phoebe.list_passband_online_history("Johnson:V")
# Out:
# {'Thu Oct 31 11:32:54 2024': 'This version fixes a bug in extinction tables.'}

# %%
b=phoebe.default_binary()
b.set_value('teff', component='secondary', value=5000)
b.set_value('q', value=0.75)
b.add_dataset('lc', times=phoebe.linspace(0,2,101))
b.add_dataset('rv', times=phoebe.linspace(0,2,101))
b.run_compute()
b.plot(x='phases', show=True)
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 101/101 [00:00<00:00, 136.25it/s]
# (<autofig.figure.Figure | 2 axes | 3 call(s)>,
#  <Figure size 800x1200 with 2 Axes>)
